# %% [markdown]
# # Auditoria de codigo_cvm por Ticker (2010–2025)
#
# Este notebook audita, ticker a ticker, se o `codigo_cvm` atribuído está correto — e se há demonstrativos financeiros suficientes para usá-lo. A auditoria funciona como um funil: a cada camada, os tickers que já têm evidência suficiente são **descartados** (dados como resolvidos) e só os que sobram seguem para a camada seguinte. A cada etapa o notebook imprime:
#
# - os tickers descartados nesta camada, com a evidência que sustentou a decisão;
# - a tabela dos tickers que ainda restam a conferir.
#
# Nenhum arquivo é gerado até a consolidação final.
#
# **Camadas:**
# 1. **FCA** (Formulário Cadastral) — fonte primária: CNPJ ↔ ticker ↔ `codigo_cvm`, ano a ano.
# 2. **Cadastro geral de companhias abertas** (`cad_cia_aberta.csv`) — fonte de apoio para quem sobrou da Camada 1.
# 3. **Cobertura de demonstrativos (DFP/ITR)** — mesmo com `codigo_cvm` correto, verifica se existe demonstrativo para montar os indicadores no período.
#
# **Sobre a Camada 3:** a exploração de formato, colunas e inconsistências dos arquivos DFP/ITR baixados **não é feita aqui**. Isso já foi tratado em `02_data_understanding.ipynb`. Este notebook apenas consome o resultado dessa exploração (um inventário de pares `codigo_cvm` x ano já extraído e validado) e valida que o contrato de entrada esperado (colunas, tipos) está sendo cumprido antes de seguir.

# %% [markdown]
# ## Setup
#
# Funções utilitárias usadas em todas as camadas: normalização de `codigo_cvm`, normalização de nome para comparação fuzzy, e um loader genérico para os CSVs anuais da CVM (todos seguem o mesmo layout: `;`, latin1, ano no nome do arquivo).

# %%
try:
    from rapidfuzz import fuzz
except ImportError:
    import subprocess, sys
    subprocess.run([sys.executable, "-m", "pip", "install", "rapidfuzz", "--break-system-packages"])
    from rapidfuzz import fuzz

import pandas as pd
import glob
import os
import re
from pathlib import Path
import unicodedata

pd.set_option("display.max_rows", 200)
pd.set_option("display.max_colwidth", 60)

caminho_atual = Path.cwd()
pasta_anterior = caminho_atual.parent


def normalizar_cvm(valor):
    """Remove zeros à esquerda e espaços, tratando codigo_cvm como número quando possível."""
    if valor is None:
        return None
    valor = str(valor).strip()
    if valor == "" or valor.upper() == "NAN":
        return None
    try:
        return str(int(valor))
    except ValueError:
        return valor


def normalizar_nome(nome):
    if not isinstance(nome, str):
        return ""
    nome = unicodedata.normalize("NFKD", nome).encode("ascii", "ignore").decode("utf-8")
    nome = re.sub(r"[^A-Za-z0-9 ]", " ", nome)
    nome = re.sub(r"\s+", " ", nome).strip().upper()
    return nome


def melhor_score_nome(nome_base, nome_alvo):
    """Combina 3 métricas de similaridade (rapidfuzz) para lidar bem com nome
    curto/coloquial (ex: NOMRES do COTAHIST) vs razão social oficial e completa."""
    if not isinstance(nome_alvo, str) or nome_alvo == "" or not isinstance(nome_base, str):
        return 0
    a, b = normalizar_nome(nome_base), normalizar_nome(nome_alvo)
    return max(
        fuzz.token_set_ratio(a, b),
        fuzz.partial_ratio(a, b),
        fuzz.token_sort_ratio(a, b),
    )


def carregar_arquivos_cvm(padrao_glob):
    """Lê e concatena um conjunto de CSVs anuais da CVM (mesmo layout)."""
    arquivos = sorted(glob.glob(padrao_glob))
    if not arquivos:
        raise FileNotFoundError(f"Nenhum arquivo encontrado para: {padrao_glob}")
    frames = []
    for arq in arquivos:
        df = pd.read_csv(arq, sep=";", encoding="latin1", dtype=str)
        df["arquivo_ano"] = os.path.basename(arq).split("_")[-1].replace(".csv", "")
        frames.append(df)
    return pd.concat(frames, ignore_index=True)

# %% [markdown]
# ## Passo 0 — Ponto de partida: a tabela completa de tickers
#
# Carrega `ticker_and_code_cvm_mapping.csv` sem cruzar com nada ainda. Este é o "estado zero" do funil: todos os tickers começam como pendentes de verificação. A tabela completa fica visível aqui para referência das próximas etapas.

# %%
caminho_mapping = pasta_anterior / "data/interim/05_investable_universe_of_stocks/ticker_and_code_cvm_mapping.csv"

seu_df = pd.read_csv(caminho_mapping, sep=";", dtype=str)
seu_df["TICKER"] = seu_df["TICKER"].str.strip().str.upper()
seu_df["codigo_cvm"] = seu_df["codigo_cvm"].astype(str).str.strip()
seu_df["primeiro_ano_observado"] = seu_df["primeiro_ano_observado"].astype(int)
seu_df["ultimo_ano_observado"] = seu_df["ultimo_ano_observado"].astype(int)
seu_df["codigo_cvm_norm"] = seu_df["codigo_cvm"].apply(normalizar_cvm)

print(f"Total de tickers a auditar: {len(seu_df)}")
seu_df
# Out:
# Total de tickers a auditar: 774
#      TICKER codigo_cvm   codigo_isin       NOMRES  primeiro_ano_observado  \
# 0     AALR3      24058  BRAALRACNOR6       ALLIAR                    2016
# 1     ABCB4      20958  BRABCBACNPR4   ABC BRASIL                    2010
# 2     ABEV3      23264  BRABEVACNOR1    AMBEV S/A                    2013
# 3     ABNB3      20028  BRABNBACNOR4       ABNOTE                    2010
# 4    ABRE11      22551  BRABRECDAM15  ABRIL EDUCA                    2011
# ..      ...        ...           ...          ...                     ...
# 769   WLMM3      11070  BRWLMMACNOR6  WLM IND COM                    2018
# 770   WLMM4      11070  BRWLMMACNPR3  WLM IND COM                    2017
# 771   YBRA4      16705  BRYBRAACNPR4    YBYRA S/A                    2023
# 772   YDUQ3      21016  BRYDUQACNOR3   YDUQS PART                    2019
# 773   ZAMP3      24317  BRZAMPACNOR5    ZAMP S.A.                    2022
#
#      ultimo_ano_observado codigo_cvm_norm
# 0                    2025           24058
# 1                    2025           20958
# 2                    2025           23264
# 3                    2010           20028
# 4                    2014           22551
# ..                    ...             ...
# 769                  2025           11070
# 770                  2025           11070
# 771                  2023           16705
# 772                  2025           21016
# 773                  2025           24317
#
# [774 rows x 7 columns]

# %% [markdown]
# ## Passo 1 — Carregar referência FCA
#
# Une `fca_cia_aberta_valor_mobiliario_AAAA.csv` (ticker ↔ CNPJ ↔ período de negociação) com `fca_cia_aberta_geral_AAAA.csv` (CNPJ ↔ `codigo_cvm` ↔ nome, ano a ano) para montar, por ticker, o conjunto de `codigo_cvm` que já esteve associado a ele — junto com o ano de cada associação (`candidatos_por_ano`). Isso permite checar depois se o código estava vigente **no período em que o ticker foi de fato negociado**, e não em qualquer ano da história do FCA.

# %%
diretorio_fca = pasta_anterior / "data/raw/06_fca_extracted"

fca_vm = carregar_arquivos_cvm(os.path.join(diretorio_fca, "fca_cia_aberta_valor_mobiliario_*.csv"))
fca_vm["CNPJ_Companhia"] = fca_vm["CNPJ_Companhia"].str.replace(r"\D", "", regex=True)
fca_vm["Codigo_Negociacao"] = fca_vm["Codigo_Negociacao"].str.strip().str.upper()
fca_vm["Data_Inicio_Negociacao"] = pd.to_datetime(fca_vm["Data_Inicio_Negociacao"], errors="coerce")
fca_vm["Data_Fim_Negociacao"] = pd.to_datetime(fca_vm["Data_Fim_Negociacao"], errors="coerce")
fca_vm = fca_vm[fca_vm["Codigo_Negociacao"].notna() & (fca_vm["Codigo_Negociacao"] != "")].copy()

fca_geral = carregar_arquivos_cvm(os.path.join(diretorio_fca, "fca_cia_aberta_geral_*.csv"))
fca_geral["CNPJ_Companhia"] = fca_geral["CNPJ_Companhia"].str.replace(r"\D", "", regex=True)
fca_geral["Codigo_CVM"] = fca_geral["Codigo_CVM"].astype(str).str.strip()
fca_geral["Data_Referencia"] = pd.to_datetime(fca_geral["Data_Referencia"], errors="coerce")
fca_geral["Nome_Empresarial"] = fca_geral["Nome_Empresarial"].str.strip()
fca_geral["Nome_Empresarial_Anterior"] = fca_geral["Nome_Empresarial_Anterior"].str.strip()

print("FCA valor mobiliário — linhas ticker x CNPJ x período:", len(fca_vm))
print("FCA geral — linhas CNPJ x codigo_cvm x ano:", len(fca_geral))

ref_cnpj_cvm = (
    fca_geral[["CNPJ_Companhia", "Codigo_CVM", "Nome_Empresarial", "Nome_Empresarial_Anterior", "Data_Referencia"]]
    .dropna(subset=["CNPJ_Companhia", "Codigo_CVM"])
    .drop_duplicates()
    .sort_values(["CNPJ_Companhia", "Data_Referencia"])
)
ref_cnpj_cvm["ano_referencia"] = ref_cnpj_cvm["Data_Referencia"].dt.year

n_cvm_por_cnpj = ref_cnpj_cvm.groupby("CNPJ_Companhia")["Codigo_CVM"].nunique()
print("CNPJs com mais de um codigo_cvm distinto ao longo do tempo:", (n_cvm_por_cnpj > 1).sum(), "de", len(n_cvm_por_cnpj))


def data_compativel(row):
    if pd.isna(row["Data_Referencia"]):
        return False
    inicio = row["Data_Inicio_Negociacao"]
    fim = row["Data_Fim_Negociacao"] if pd.notna(row["Data_Fim_Negociacao"]) else pd.Timestamp("2100-01-01")
    if pd.isna(inicio):
        return True
    return inicio <= row["Data_Referencia"] <= fim


fca_vm_reduzido = fca_vm[["CNPJ_Companhia", "Codigo_Negociacao", "Data_Inicio_Negociacao", "Data_Fim_Negociacao"]].copy()
ref_ticker_cvm = fca_vm_reduzido.merge(ref_cnpj_cvm, on="CNPJ_Companhia", how="left")
ref_ticker_cvm["compativel"] = ref_ticker_cvm.apply(data_compativel, axis=1)
ref_ticker_cvm = ref_ticker_cvm[ref_ticker_cvm["compativel"]].copy()


def nomes_unicos(serie_atual, serie_anterior):
    nomes = set(serie_atual.dropna()) | set(serie_anterior.dropna())
    return sorted(n for n in nomes if n)


ref_ticker_cvm_final = (
    ref_ticker_cvm
    .groupby("Codigo_Negociacao")
    .apply(lambda g: pd.Series({
        "codigo_cvm_fca": sorted(set(g["Codigo_CVM"])),
        "nome_empresarial_fca": nomes_unicos(g["Nome_Empresarial"], g["Nome_Empresarial_Anterior"]),
        "candidatos_por_ano": sorted(set(zip(g["ano_referencia"].dropna().astype(int), g["Codigo_CVM"]))),
    }))
    .reset_index()
    .rename(columns={"Codigo_Negociacao": "TICKER"})
)

print("\nTotal de tickers com alguma referência no FCA:", len(ref_ticker_cvm_final))
# Out:
# FCA valor mobiliário — linhas ticker x CNPJ x período: 4427
# FCA geral — linhas CNPJ x codigo_cvm x ano: 10955
# CNPJs com mais de um codigo_cvm distinto ao longo do tempo: 6 de 1260
#
# Total de tickers com alguma referência no FCA: 752

# %% [markdown]
# Alguns tickers do FCA são preenchidos com valores residuais que não correspondem a tickers reais da B3 (ex.: `-`, `0`, `00000`, `999999`) — resíduos de cadastro que não afetam a auditoria, pois só entram no cruzamento se existir um `TICKER` correspondente na sua tabela.
#
# ## Passo 2 — Camada 1: cruzar com o FCA e separar o funil
#
# Classifica cada ticker em:
#
# - **ALTA** (descartado, resolvido): o `codigo_cvm` informado bate com um candidato do FCA para aquele ticker, **e** o ano desse candidato está dentro do intervalo `primeiro_ano_observado`–`ultimo_ano_observado` medido no COTAHIST. Essa exigência de ano evita validar um código que só passou a valer depois (ou parou de valer antes) do período em que o ticker foi observado.
# - **PENDENTE** (segue no funil): sem referência FCA, ou nenhum candidato compatível no período bate com o `codigo_cvm` informado.
#
# Abaixo: os descartados com a evidência que embasou a decisão, e a tabela dos que restam para a Camada 2.

# %%
auditoria = seu_df.merge(ref_ticker_cvm_final, on="TICKER", how="left")


def status_layer1(row):
    candidatos = row["candidatos_por_ano"]
    if not isinstance(candidatos, list) or len(candidatos) == 0:
        return "PENDENTE", None
    alvo = row["codigo_cvm_norm"]
    for ano, cvm in candidatos:
        dentro_do_periodo = row["primeiro_ano_observado"] <= ano <= row["ultimo_ano_observado"]
        if dentro_do_periodo and normalizar_cvm(cvm) == alvo:
            return "ALTA", ano
    return "PENDENTE", None


resultado_layer1 = auditoria.apply(status_layer1, axis=1, result_type="expand")
auditoria["status_layer1"] = resultado_layer1[0]
auditoria["ano_confirmacao_fca"] = resultado_layer1[1]

print(auditoria["status_layer1"].value_counts())

descartados_fca = auditoria[auditoria["status_layer1"] == "ALTA"]
pendentes_pos_fca = auditoria[auditoria["status_layer1"] == "PENDENTE"].copy()

print(f"\n--- Descartados via FCA ({len(descartados_fca)}) ---")
display(descartados_fca[["TICKER", "codigo_cvm", "ano_confirmacao_fca", "nome_empresarial_fca",
                          "primeiro_ano_observado", "ultimo_ano_observado"]])

print(f"\n--- Restam para a Camada 2 ({len(pendentes_pos_fca)}) ---")
display(pendentes_pos_fca[["TICKER", "codigo_cvm", "codigo_isin", "primeiro_ano_observado",
                            "ultimo_ano_observado", "codigo_cvm_fca", "nome_empresarial_fca"]])
# Out:
# status_layer1
# ALTA        547
# PENDENTE    227
# Name: count, dtype: int64
#
# --- Descartados via FCA (547) ---
#     TICKER codigo_cvm  ano_confirmacao_fca  \
# 0    AALR3      24058               2017.0
# 1    ABCB4      20958               2010.0
# 2    ABEV3      23264               2014.0
# 12   AELP3      19313               2010.0
# 13   AERI3      25283               2021.0
# ..     ...        ...                  ...
# 769  WLMM3      11070               2018.0
# 770  WLMM4      11070               2017.0
# 771  YBRA4      16705               2023.0
# 772  YDUQ3      21016               2019.0
# 773  ZAMP3      24317               2022.0
#
#                                             nome_empresarial_fca  \
# 0    [ALLIANÇA SAÚDE E PARTICIPAÇÕES S.A., CENTRO DE IMAGEM D...
# 1    [BANCO ABC BRASIL S/A, BCO ABC BRASIL S.A., Banco ABC Ro...
# 2    [AMBEV S.A., Ambev S.A., InBev Participações Societárias...
# 12                   [AES ELPA S.A., AES ELPA SA, AES Elpa Ltda]
# 13          [AERIS IND. E COM. DE EQUIP. PARA GER. DE ENG. S.A.]
# ..                                                           ...
# 769  [Supergasbras Indústria e Comércio S.A., WLM INDÚSTRIA E...
# 770  [Supergasbras Indústria e Comércio S.A., WLM INDÚSTRIA E...
# 771  [ALEF S.A., ALEF SA, Alef S.A., Opportunity Alef S.A., Y...
# 772  [ESTACIO PARTICIPACOES S.A., ESTACIO PARTICIPAÇÕES SA, Y...
# 773  [BK BRASIL OPERAÇÃO E ASSESSORIA A RESTAURANTES SA, CMNP...
#
#      primeiro_ano_observado  ultimo_ano_observado
# 0                      2016                  2025
# 1                      2010                  2025
# 2                      2013                  2025
# 12                     2010                  2018
# 13                     2020                  2025
# ..                      ...                   ...
# 769                    2018                  2025
# 770                    2017                  2025
# 771                    2023                  2023
# 772                    2019                  2025
# 773                    2022                  2025
#
# [547 rows x 6 columns]
# --- Restam para a Camada 2 (227) ---
#      TICKER codigo_cvm   codigo_isin  primeiro_ano_observado  \
# 3     ABNB3      20028  BRABNBACNOR4                    2010
# 4    ABRE11      22551  BRABRECDAM15                    2011
# 5     ABRE3      22551  BRABREACNOR9                    2014
# 6     ABYA3      20206  BRABYAACNOR3                    2010
# 7     ACGU3      20940  BRACGUACNOR6                    2010
# ..      ...        ...           ...                     ...
# 747   VIVO4      17671  BRVIVOACNPR8                    2010
# 753   VTLM3      21725  BRVTLMACNOR3                    2016
# 760   WDCN3      25895  BRWDCNACNOR2                    2025
# 765   WISA3      14397  BRWISAACNOR4                    2011
# 766   WISA4      14397  BRWISAACNPR1                    2011
#
#      ultimo_ano_observado codigo_cvm_fca nome_empresarial_fca
# 3                    2010            NaN                  NaN
# 4                    2014            NaN                  NaN
# 5                    2015            NaN                  NaN
# 6                    2010            NaN                  NaN
# 7                    2010            NaN                  NaN
# ..                    ...            ...                  ...
# 747                  2011            NaN                  NaN
# 753                  2016            NaN                  NaN
# 760                  2025            NaN                  NaN
# 765                  2012            NaN                  NaN
# 766                  2012            NaN                  NaN
#
# [227 rows x 7 columns]

# %% [markdown]
# ## Passo 3 — Camada 2: cruzar os pendentes com `cad_cia_aberta`
#
# Para quem sobrou da Camada 1, verifica se o `codigo_cvm` informado existe no cadastro geral de companhias abertas da CVM e, se existir, compara `NOMRES` (nome curto do COTAHIST) com `DENOM_SOCIAL` (razão social oficial) usando o melhor entre 3 métricas de similaridade (`token_set_ratio`, `partial_ratio`, `token_sort_ratio`). Isso é necessário porque nomes curtos/coloquiais como "AMBEV" batem mal com razões sociais completas como "COMPANHIA DE BEBIDAS DAS AMÉRICAS-AMBEV" em métricas simples de distância de string.
#
# Três desfechos:
# - **ALTA_VIA_CADASTRO** (descartado): código existe e o nome bate (score ≥ `LIMIAR_NOME`).
# - **REVISAR_NOME_DIVERGENTE** (segue no funil): código existe, mas o nome não bate.
# - **REVISAR_CODIGO_INEXISTENTE** (segue no funil): o `codigo_cvm` nem existe no cadastro — sinal forte de erro de digitação/transcrição, ou caso atípico fora do registro padrão (ex.: BDR/unit).
#
# **Nota:** o cadastro é reduzido a um registro por `codigo_cvm` mantendo a razão social mais recente (`keep="last"`). Isso significa que tickers antigos, cujo nome no COTAHIST reflete uma razão social já trocada há anos, tendem a cair em `REVISAR_NOME_DIVERGENTE` mesmo com o `codigo_cvm` correto — vale ter isso em mente ao revisar a lista, e considerar comparar contra o histórico de nomes se o volume de divergências por esse motivo for grande.

# %%
caminho_cad = pasta_anterior / "data/raw/06_cad_cia_aberta.csv"

cad = pd.read_csv(caminho_cad, sep=";", encoding="latin1", dtype=str)
cad.columns = [c.strip() for c in cad.columns]
cad["CD_CVM_NORM"] = cad["CD_CVM"].astype(str).str.strip().apply(normalizar_cvm)
cad["DENOM_SOCIAL"] = cad["DENOM_SOCIAL"].str.strip()
cad_unico = cad.drop_duplicates(subset="CD_CVM_NORM", keep="last")
print("Companhias únicas no cadastro:", len(cad_unico))

LIMIAR_NOME = 80

pendentes_pos_fca = pendentes_pos_fca.merge(
    cad_unico[["CD_CVM_NORM", "DENOM_SOCIAL"]],
    left_on="codigo_cvm_norm", right_on="CD_CVM_NORM", how="left"
)
pendentes_pos_fca["existe_no_cadastro"] = pendentes_pos_fca["DENOM_SOCIAL"].notna()
pendentes_pos_fca["score_nome_cadastro"] = pendentes_pos_fca.apply(
    lambda r: melhor_score_nome(r.get("NOMRES"), r["DENOM_SOCIAL"]) if r["existe_no_cadastro"] else 0,
    axis=1,
)


def status_layer2(row):
    if not row["existe_no_cadastro"]:
        return "REVISAR_CODIGO_INEXISTENTE"
    if row["score_nome_cadastro"] >= LIMIAR_NOME:
        return "ALTA_VIA_CADASTRO"
    return "REVISAR_NOME_DIVERGENTE"


pendentes_pos_fca["status_layer2"] = pendentes_pos_fca.apply(status_layer2, axis=1)
print(pendentes_pos_fca["status_layer2"].value_counts())

descartados_cadastro = pendentes_pos_fca[pendentes_pos_fca["status_layer2"] == "ALTA_VIA_CADASTRO"]
pendentes_pos_cadastro = pendentes_pos_fca[pendentes_pos_fca["status_layer2"] != "ALTA_VIA_CADASTRO"].copy()

print(f"\n--- Descartados via cadastro ({len(descartados_cadastro)}) ---")
display(descartados_cadastro[["TICKER", "codigo_cvm", "DENOM_SOCIAL", "score_nome_cadastro"]]
        .sort_values("score_nome_cadastro"))
# Out:
# Companhias únicas no cadastro: 2566
# status_layer2
# ALTA_VIA_CADASTRO             142
# REVISAR_NOME_DIVERGENTE        84
# REVISAR_CODIGO_INEXISTENTE      1
# Name: count, dtype: int64
#
# --- Descartados via cadastro (142) ---
#      TICKER codigo_cvm  \
# 10    AGEI3      21911
# 51    CAFE4       2062
# 196   TCSL3      17639
# 115   IMCH3      22438
# 197   TCSL4      17639
# 214   TXRX3       7544
# 205   TLPP4      17671
# 204   TLPP3      17671
# 147   NORD3       9083
# 199   TENE5      11215
# 171   RPMG4       9989
# 200   TENE7      11215
# 218   VAGR3      20354
# 190   SUZB5      13986
# 66    CSNA3       4030
# 114   IMBI4       3174
# 113   IMBI3       3174
# 108   IENG5      16730
# 100   GETT3      26140
# 101   GETT4      26140
# 107   IENG3      16730
# 99   GETT11      26140
# 90    FFTL3      14028
# 56    CEAB3      24848
# 207   TMAR5      11320
# 206   TMAR3      11320
# 62    CMIN3      25585
# 208   TNCP4      17604
# 125   KSSA3      20249
# 93    FRAS4       6211
# 5     ADHM3      21725
# 24    AUTM3      22381
# 55    CCTY3      27570
# 53    CBMA4       4448
# 52    CBMA3       4448
# 46    BRPR3      19925
# 37    BMTO3       1970
# 38    BMTO4       1970
# 36   BMGB11      24600
# 35    BISA3      20265
# 68    CTAX3      19100
# 69    CTAX4      19100
# 70    CTIP3      21792
# 58    CLAN4      18490
# 63    CNFB4       4650
# 64   CPLE11      14311
# 65    CRUZ3       4057
# 67   CTAX11      19100
# 77    DROG3       5258
# 76    DOCA4       3182
# 73    DAYC4      20796
# 26    AXIA3       2437
# 30    BEMA3      20656
# 31    BHGR3      20907
# 34    BIOM4      19305
# 29   BBTG11      22616
# 16    ALUP4      21490
# 25    AVIL3        108
# 27    AXIA6       2437
# 4     ACGU3      20940
# 7    AEDU11      18961
# 8     AEDU3      18961
# 9     AFLU3      20150
# 3     ABYA3      20206
# 98    GETI4      18970
# 92    FIEI3      20630
# 96    GAZO4       6378
# 97    GETI3      18970
# 83    ELPL4      14176
# 84    ELPL5      14176
# 85    ELPL6      14176
# 86    EPAR3      15458
# 80    EBTP3      17647
# 81    EBTP4      17647
# 79    DXTG4      14931
# 71    CTPC3      12181
# 72    CZRS4      20753
# 110   IGUA5       3336
# 111   IGUA6       3336
# 104   HAGA3      13366
# 122   KLBN4      12653
# 126   LEVE4       8575
# 132   MAPT3      13854
# 130   LUXM4       8192
# 134   MARI3      20761
# 135   MBRF3      20788
# 136   MEDI3      20273
# 133   MAPT4      13854
# 139   MNDL4       5312
# 142   MRSL4       8486
# 109   IGUA3       3336
# 105   HAGA4      13366
# 112   ILMD4        140
# 116   INEP4       7595
# 121   KLBN3      12653
# 103   GVTT3      20117
# 155   PMET6       1686
# 154   PMAM4       9393
# 153   PLAS3      13471
# 148   OBTC3      27910
# 146   NETC4      14621
# 145   NETC3      14621
# 159   PRTX3      21776
# 156   PNOR5       9784
# 166   REDE4       3190
# 167   REEM4      12840
# 168   RHDS3      14559
# 157   PNOR6       9784
# 162   RAIA3      22306
# 163   RDCD3      20893
# 164   RDTR3      22128
# 160   PRVI3      20974
# 176   SANB3      20532
# 175   RVEE3      27650
# 174   RUMO3      23450
# 173   RSIP4      18279
# 172   RSIP3      18279
# 177   SANB4      20532
# 180   SFSA4      20680
# 178   SCLO4       3549
# 189   SULT4      13030
# 17    AMAR3      22055
# 18    AMBV3      18112
# 19    AMBV4      18112
# 20    AMCE3      16195
# 21    AMIL3      21172
# 23    ARTR3      19771
# 15    ALUP3      21490
# 198   TEMP3      19917
# 192   SZPQ4      19267
# 193   TAMM3      16390
# 194   TAMM4      16390
# 183   SGEN4      10596
# 186   SMLE3      23140
# 188   SULT3      13030
# 201   TERI3      22136
# 213   TVIT3      21768
# 212   TUPY4       6343
# 216   UGPA4      18465
# 219   VALE5       4170
# 225   WISA3      14397
# 226   WISA4      14397
#
#                                                     DENOM_SOCIAL  \
# 10                          AGRE EMPREENDIMENTOS IMOBILIÁRIOS SA
# 51                                      CAFE SOLUVEL BRASILIA SA
# 196                                         TIM PARTICIPAÇÕES SA
# 115                      INTERNATIONAL MEAL COMPANY HOLDINGS, SA
# 197                                         TIM PARTICIPAÇÕES SA
# 214                                        TÊXTIL RENAUXVIEW S/A
# 205                                       TELEFÔNICA BRASIL S.A.
# 204                                       TELEFÔNICA BRASIL S.A.
# 147                          NORDON INDUSTRIAS METALURGICAS S.A.
# 199                             TECBLU - TECELAGEM BLUMENAU S/A.
# 171  REFINARIA DE PETRÓLEOS DE MANGUINHOS S.A. - EM RECUPERAÇ...
# 200                             TECBLU - TECELAGEM BLUMENAU S/A.
# 218                                        TERRA SANTA AGRO S.A.
# 190                                                  SUZANO S.A.
# 66                                      CIA SIDERURGICA NACIONAL
# 114                                        CIA DOCAS DE IMBITUBA
# 113                                        CIA DOCAS DE IMBITUBA
# 108                                            INEPAR ENERGIA SA
# 100   GETNET ADQUIRÊNCIA E SERVIÇOS PARA MEIOS DE PAGAMENTO S.A.
# 101   GETNET ADQUIRÊNCIA E SERVIÇOS PARA MEIOS DE PAGAMENTO S.A.
# 107                                            INEPAR ENERGIA SA
# 99    GETNET ADQUIRÊNCIA E SERVIÇOS PARA MEIOS DE PAGAMENTO S.A.
# 90                                       VALE FERTILIZANTES S.A.
# 56                                                C&A MODAS S.A.
# 207                                       TELEMAR NORTE LESTE SA
# 206                                       TELEMAR NORTE LESTE SA
# 62                                            CSN MINERAÇÃO S.A.
# 208                          TELE NORTE CELULAR PARTICIPAÇÕES SA
# 125                                            KLABIN SEGALL S/A
# 93                                          FRASLE MOBILITY S.A.
# 5               ADVANCED DIGITAL HEALTH MEDICINA PREVENTIVA S.A.
# 24                                                 AUTOMETAL S/A
# 55             BELORA RDVC CITY DESENVOLVIMENTO IMOBILIÁRIO S.A.
# 53                                                   COBRASMA SA
# 52                                                   COBRASMA SA
# 46                                            BR PROPERTIES S.A.
# 37                                                  BRASMOTOR SA
# 38                                                  BRASMOTOR SA
# 36                                                 BANCO BMG S/A
# 35                                 BROOKFIELD INCORPORAÇÕES S.A.
# 68           CONTAX PARTICIPAÇÕES S.A. - EM RECUPERAÇÃO JUDICIAL
# 69           CONTAX PARTICIPAÇÕES S.A. - EM RECUPERAÇÃO JUDICIAL
# 70                             CETIP S.A. - MERCADOS ORGANIZADOS
# 58                                    CLARION S/A AGROINDUSTRIAL
# 63                                          CONFAB INDUSTRIAL SA
# 64                         COMPANHIA PARANAENSE DE ENERGIA COPEL
# 65                                                 SOUZA CRUZ SA
# 67           CONTAX PARTICIPAÇÕES S.A. - EM RECUPERAÇÃO JUDICIAL
# 77                                            RAIA DROGASIL S.A.
# 76                                        DOCAS INVESTIMENTOS SA
# 73                                           BANCO DAYCOVAL S.A.
# 26                                             AXIA ENERGIA S.A.
# 30                                                 BEMATECH  S/A
# 31                           BHG S.A. - BRAZIL HOSPITALITY GROUP
# 34                                                      BIOMM SA
# 29                                         BANCO BTG PACTUAL S/A
# 16                                       ALUPAR INVESTIMENTO S/A
# 25                                              AÇOS VILLARES SA
# 27                                             AXIA ENERGIA S.A.
# 4                                             AÇUCAR GUARANI S/A
# 7                      ANHANGUERA EDUCACIONAL PARTICIPAÇÕES S.A.
# 8                      ANHANGUERA EDUCACIONAL PARTICIPAÇÕES S.A.
# 9                      AFLUENTE GERAÇÃO DE ENERGIA ELÉTRICA S.A.
# 3                            ABYARA PLANEJAMENTO IMOBILIÁRIO S/A
# 98                                         AES TIETÊ ENERGIA S.A
# 92                        FICA EMPREENDIMENTOS IMOBILIARIOS S.A.
# 96                               GAZOLA SA INDÚSTRIA METALURGICA
# 97                                         AES TIETÊ ENERGIA S.A
# 83                      ELETROPAULO METROP. ELET. SAO PAULO S.A.
# 84                      ELETROPAULO METROP. ELET. SAO PAULO S.A.
# 85                      ELETROPAULO METROP. ELET. SAO PAULO S.A.
# 86                                      EMBPAR PARTICIPAÇÕES S/A
# 80                                     EMBRATEL PARTICIPAÇÕES SA
# 81                                     EMBRATEL PARTICIPAÇÕES SA
# 79                                                 DIXIE TOGA SA
# 71                                MARAMBAIA ENERGIA RENOVÁVEL SA
# 72                     MASSA FALIDA DO BANCO CRUZEIRO DO SUL S/A
# 110                                  CIA. IGUAÇU DE CAFÉ SOLÚVEL
# 111                                  CIA. IGUAÇU DE CAFÉ SOLÚVEL
# 104                               HAGA S.A. INDÚSTRIA E COMÉRCIO
# 122                                                  KLABIN S.A.
# 126                                        MAHLE METAL LEVE S.A.
# 132                                      CEMEPE INVESTIMENTOS SA
# 130                                    TREVISA  INVESTIMENTOS SA
# 134                                                    MARISA SA
# 135                                      MARFRIG GLOBAL FOODS SA
# 136                                             MEDIAL SAUDE S/A
# 133                                      CEMEPE INVESTIMENTOS SA
# 139                            MUNDIAL S.A - PRODUTOS DE CONSUMO
# 142                                                   MARISOL SA
# 109                                  CIA. IGUAÇU DE CAFÉ SOLÚVEL
# 105                               HAGA S.A. INDÚSTRIA E COMÉRCIO
# 112                                    YARA BRASIL FERTILIZANTES
# 116  INEPAR S.A. INDUSTRIA E CONSTRUCOES EM RECUPERACAO JUDICIAL
# 121                                                  KLABIN S.A.
# 103                                              GVT HOLDING S/A
# 155              PRÓ METALURGIA SA - EM LIQUIDAÇÃO EXTRAJUDICIAL
# 154                  PARANAPANEMA S.A. - EM RECUPERAÇÃO JUDICIAL
# 153                        PLASCAR PARTICIPAÇÕES INDUSTRIAIS S.A
# 148                     ORANJEBTC S.A. - EDUCAÇÃO E INVESTIMENTO
# 146                             NET SERVIÇOS DE COMUNICAÇÃO S.A.
# 145                             NET SERVIÇOS DE COMUNICAÇÃO S.A.
# 159                              PORTX OPERAÇÕES PORTUÁRIAS S.A.
# 156                                       PRONOR PETROQUIMICA SA
# 166                              REDE ENERGIA PARTICIPAÇÕES S.A.
# 167                       RIMET EMPREEND. INDS. E COMERCIAIS S/A
# 168                                             M&G POLIÉSTER SA
# 157                                       PRONOR PETROQUIMICA SA
# 162                                                      RAIA SA
# 163                                                 REDECARD S/A
# 164                                         REDENTOR ENERGIA S/A
# 160                         COMPANHIA PROVIDENCIA IND E COMERCIO
# 176                                BANCO SANTANDER (BRASIL) S.A.
# 175                                                   REVEE S.A.
# 174                     RUMO LOGÍSTICA OPERADORA MULTIMODAL S.A.
# 173                                       RASIP AGRO PASTORIL SA
# 172                                       RASIP AGRO PASTORIL SA
# 177                                BANCO SANTANDER (BRASIL) S.A.
# 180                                              BANCO SOFISA SA
# 178                                CIA INDUSTRIAL SCHLOSSER S.A.
# 189           CONSTRUTORA SULTEPA S.A. - EM RECUPERAÇÃO JUDICIAL
# 17                                               MARISA LOJAS SA
# 18                       COMPANHIA DE BEBIDAS DAS AMÉRICAS-AMBEV
# 19                       COMPANHIA DE BEBIDAS DAS AMÉRICAS-AMBEV
# 20                                                   AMERICEL SA
# 21                                        AMIL PARTICIPAÇÕES S/A
# 23                                                  ARTERIS S.A.
# 15                                       ALUPAR INVESTIMENTO S/A
# 198                                      TEMPO PARTICIPAÇOES S/A
# 192                                    QUATTOR PETROQUÍMICA S.A.
# 193                                                     TAM S.A.
# 194                                                     TAM S.A.
# 183                                SERGEN SERVS GERAIS DE ENG SA
# 186                                                  SMILES S.A.
# 188           CONSTRUTORA SULTEPA S.A. - EM RECUPERAÇÃO JUDICIAL
# 201                                     TEREOS INTERNACIONAL S/A
# 213  TIVIT TERCEIRIZAÇÃO DE PROCESSOS, SERVIÇOS E TECNOLOGIA S/A
# 212                                                      TUPY SA
# 216                                    ULTRAPAR PARTICIPAÇÕES SA
# 219                                                    VALE S.A.
# 225                                                     WIEST SA
# 226                                                     WIEST SA
#
#      score_nome_cadastro
# 10             80.000000
# 51             80.000000
# 196            80.000000
# 115            80.000000
# 197            80.000000
# 214            80.000000
# 205            80.000000
# 204            80.000000
# 147            82.352941
# 199            83.333333
# 171            83.333333
# 200            83.333333
# 218            83.333333
# 190            84.210526
# 66             85.714286
# 114            86.956522
# 113            86.956522
# 108            87.500000
# 100            87.500000
# 101            87.500000
# 107            87.500000
# 99             87.500000
# 90             87.500000
# 56             88.888889
# 207            90.000000
# 206            90.000000
# 62             91.666667
# 208            91.666667
# 125            91.666667
# 93             92.307692
# 5              95.238095
# 24            100.000000
# 55            100.000000
# 53            100.000000
# 52            100.000000
# 46            100.000000
# 37            100.000000
# 38            100.000000
# 36            100.000000
# 35            100.000000
# 68            100.000000
# 69            100.000000
# 70            100.000000
# 58            100.000000
# 63            100.000000
# 64            100.000000
# 65            100.000000
# 67            100.000000
# 77            100.000000
# 76            100.000000
# 73            100.000000
# 26            100.000000
# 30            100.000000
# 31            100.000000
# 34            100.000000
# 29            100.000000
# 16            100.000000
# 25            100.000000
# 27            100.000000
# 4             100.000000
# 7             100.000000
# 8             100.000000
# 9             100.000000
# 3             100.000000
# 98            100.000000
# 92            100.000000
# 96            100.000000
# 97            100.000000
# 83            100.000000
# 84            100.000000
# 85            100.000000
# 86            100.000000
# 80            100.000000
# 81            100.000000
# 79            100.000000
# 71            100.000000
# 72            100.000000
# 110           100.000000
# 111           100.000000
# 104           100.000000
# 122           100.000000
# 126           100.000000
# 132           100.000000
# 130           100.000000
# 134           100.000000
# 135           100.000000
# 136           100.000000
# 133           100.000000
# 139           100.000000
# 142           100.000000
# 109           100.000000
# 105           100.000000
# 112           100.000000
# 116           100.000000
# 121           100.000000
# 103           100.000000
# 155           100.000000
# 154           100.000000
# 153           100.000000
# 148           100.000000
# 146           100.000000
# 145           100.000000
# 159           100.000000
# 156           100.000000
# 166           100.000000
# 167           100.000000
# 168           100.000000
# 157           100.000000
# 162           100.000000
# 163           100.000000
# 164           100.000000
# 160           100.000000
# 176           100.000000
# 175           100.000000
# 174           100.000000
# 173           100.000000
# 172           100.000000
# 177           100.000000
# 180           100.000000
# 178           100.000000
# 189           100.000000
# 17            100.000000
# 18            100.000000
# 19            100.000000
# 20            100.000000
# 21            100.000000
# 23            100.000000
# 15            100.000000
# 198           100.000000
# 192           100.000000
# 193           100.000000
# 194           100.000000
# 183           100.000000
# 186           100.000000
# 188           100.000000
# 201           100.000000
# 213           100.000000
# 212           100.000000
# 216           100.000000
# 219           100.000000
# 225           100.000000
# 226           100.000000

# %% [markdown]
# ## Passo 4 — Consolidar `status_final`
#
# Junta as duas camadas num único dataframe `auditoria_final`, com `status_final` para todos os tickers da tabela original. Ainda sem gerar arquivo — só o print do resumo geral e da lista consolidada de quem precisa de checagem manual.

# %%
mapa_layer2 = pendentes_pos_fca.set_index("TICKER")[["status_layer2", "DENOM_SOCIAL", "score_nome_cadastro"]]

auditoria_final = auditoria.merge(mapa_layer2, on="TICKER", how="left")


def status_consolidado(row):
    if row["status_layer1"] == "ALTA":
        return "ALTA_VIA_FCA"
    return row["status_layer2"]


auditoria_final["status_final"] = auditoria_final.apply(status_consolidado, axis=1)

print(auditoria_final["status_final"].value_counts())

n_revisar = auditoria_final["status_final"].isin(["REVISAR_NOME_DIVERGENTE", "REVISAR_CODIGO_INEXISTENTE"]).sum()
print(f"\nValidados automaticamente: {len(auditoria_final) - n_revisar} de {len(auditoria_final)} "
      f"({(len(auditoria_final) - n_revisar) / len(auditoria_final):.1%})")

colunas_master = ["TICKER", "codigo_cvm", "codigo_isin", "primeiro_ano_observado",
                   "ultimo_ano_observado", "status_final", "DENOM_SOCIAL", "score_nome_cadastro"]
colunas_master = [c for c in colunas_master if c in auditoria_final.columns]

revisar = auditoria_final[auditoria_final["status_final"].isin(
    ["REVISAR_NOME_DIVERGENTE", "REVISAR_CODIGO_INEXISTENTE"]
)].sort_values("score_nome_cadastro")

print(f"\n--- {len(revisar)} tickers para checagem manual pontual ---")
revisar[colunas_master]
# Out:
# status_final
# ALTA_VIA_FCA                  547
# ALTA_VIA_CADASTRO             142
# REVISAR_NOME_DIVERGENTE        84
# REVISAR_CODIGO_INEXISTENTE      1
# Name: count, dtype: int64
#
# Validados automaticamente: 689 de 774 (89.0%)
#
# --- 85 tickers para checagem manual pontual ---
#      TICKER codigo_cvm   codigo_isin  primeiro_ano_observado  \
# 557  PPLA11      80152  BRPPLAUNT007                    2017
# 747   VIVO4      17671  BRVIVOACNPR8                    2010
# 746   VIVO3      17671  BRVIVOACNOR1                    2010
# 273   ECOD3      20354  BRECODACNOR8                    2010
# 694   TIBR5      11398  BRTIBRACNPA3                    2010
# 695   TIBR6      11398  BRTIBRACNPB1                    2010
# 451   LVTC3      25895  BRLVTCACNOR4                    2021
# 3     ABNB3      20028  BRABNBACNOR4                    2010
# 517   OHLB3      19771  BROHLBACNOR6                    2010
# 760   WDCN3      25895  BRWDCNACNOR2                    2025
# 665   SWET3      21725  BRSWETACNOR3                    2015
# 349   GLOB3       6505  BRGLOBACNOR8                    2010
# 149   BTTL4      15458  BRBTTLACNPR7                    2010
# 148   BTTL3      15458  BRBTTLACNOR0                    2010
# 9     ADMF3      27634  BRADMFACNOR3                    2025
# 424   KROT3      17973  BRKROTACNOR9                    2012
# 257   DMMO3      23493  BRDMMOACNOR0                    2017
# 594   RNAR3      19658  BRRNARACNOR6                    2010
# 373   HRTP3      22187  BRHRTPACNOR2                    2010
# 423  KROT11      17973  BRKROTCDAM11                    2010
# 435   LFFE4      12262  BRLFFEACNPR9                    2010
# 434   LFFE3      12262  BRLFFEACNOR2                    2016
# 143   BRTO4      11312  BRBRTOACNPR5                    2010
# 142   BRTO3      11312  BRBRTOACNOR8                    2010
# 657   STLB3      21725  BRSTLBACNOR2                    2010
# 531   PCAR5      14826  BRPCARACNPA6                    2010
# 109   BNCA3       1023  BRBNCAACNOR2                    2010
# 515   OGSA3      23493  BROGSAACNOR5                    2017
# 675   TBLE3      17329  BRTBLEACNOR2                    2010
# 395   INET3      15423  BRINETACNOR3                    2010
# 25    ALLL4      17450  BRALLLACNPR3                    2010
# 23   ALLL11      17450  BRALLLCDAM10                    2010
# 24    ALLL3      17450  BRALLLACNOR6                    2010
# 416   JPSA4       8672  BRJPSAACNPR3                    2018
# 409   JBDU4      12319  BRJBDUACNPR3                    2010
# 474   MLFT3       8672  BRMLFTACNOR6                    2011
# 475   MLFT4       8672  BRMLFTACNPR3                    2010
# 407  JBDU11      12319  BRJBDUA03OR3                    2019
# 197   CLSC6       2461  BRCLSCACNPB7                    2010
# 129   BRIN3      22217  BRBRINACNOR3                    2010
# 568   PTPA4      13412  BRPTPAACNPR8                    2010
# 488   MPXE3      21237  BRMPXEACNOR2                    2010
# 117   BPNM4      21199  BRBPNMACNPR6                    2010
# 716  TRNA11      20257  BRTRNACDAM14                    2010
# 626   SGAS3      11070  BRSGASACNOR6                    2010
# 627   SGAS4      11070  BRSGASACNPR3                    2010
# 5     ABRE3      22551  BRABREACNOR9                    2014
# 4    ABRE11      22551  BRABRECDAM15                    2011
# 162   CCIM3      20486  BRCCIMACNOR5                    2010
# 753   VTLM3      21725  BRVTLMACNOR3                    2016
# 444   LLXL3      21482  BRLLXLACNOR8                    2010
# 44    AORE3      21725  BRAOREACNOR2                    2011
# 525   PARC3      23590  BRPARCACNOR3                    2015
# 199   CMGR4      14605  BRCMGRACNPR4                    2010
# 192   CIQU4      21733  BRCIQUACNPR5                    2010
# 585   REAG3      25887  BRREAGACNOR8                    2025
# 198   CMGR3      14605  BRCMGRACNOR7                    2010
# 592   RJCP3      22330  BRRJCPACNOR4                    2011
# 18    AGIN3      20664  BRAGINACNOR8                    2010
# 306   EQPA3      18309  BREQPAACNOR1                    2020
# 322   FFTL4      14028  BRFFTLACNPR7                    2010
# 308   EQPA7      18309  BREQPAACNPC0                    2020
# 112  BPAC11      22616  BRBPACUNT006                    2017
# 113   BPAC3      22616  BRBPACACNOR7                    2017
# 727   UCOP4      12220  BRUCOPACNPR5                    2010
# 733   UOLL4      19887  BRUOLLACNPR5                    2010
# 483   MODL4      25755  BRMODLACNPR9                    2021
# 336   FTRX4       5827  BRFTRXACNPR7                    2010
# 307   EQPA5      18309  BREQPAACNPA4                    2020
# 633   SJOS3       5983  BRSJOSACNOR1                    2010
# 621  SEBB11      17906  BRSEBBCDAM13                    2010
# 634   SJOS4       5983  BRSJOSACNPR8                    2010
# 335   FTRX3       5827  BRFTRXACNOR0                    2010
# 114   BPAC5      22616  BRBPACACNPA0                    2017
# 494   MTIG3       8605  BRMTIGACNOR0                    2010
# 495   MTIG4       8605  BRMTIGACNPR7                    2010
# 266   DUQE4       8648  BRDUQEACNPR2                    2010
# 108   BNBR4       1228  BRBNBRACNPR5                    2010
# 708   TNLP4      17655  BRTNLPACNPR0                    2010
# 707   TNLP3      17655  BRTNLPACNOR3                    2010
# 742   VIGR3      22772  BRVIGRACNOR5                    2012
# 84    BICB3      21113  BRBICBACNOR0                    2010
# 254   DHBI4       5150  BRDHBIACNPR2                    2010
# 85    BICB4      21113  BRBICBACNPR7                    2010
# 61    AZTE3      27626  BRAZTEACNOR4                    2025
#
#      ultimo_ano_observado                status_final  \
# 557                  2022  REVISAR_CODIGO_INEXISTENTE
# 747                  2011     REVISAR_NOME_DIVERGENTE
# 746                  2011     REVISAR_NOME_DIVERGENTE
# 273                  2011     REVISAR_NOME_DIVERGENTE
# 694                  2015     REVISAR_NOME_DIVERGENTE
# 695                  2014     REVISAR_NOME_DIVERGENTE
# 451                  2025     REVISAR_NOME_DIVERGENTE
# 3                    2010     REVISAR_NOME_DIVERGENTE
# 517                  2012     REVISAR_NOME_DIVERGENTE
# 760                  2025     REVISAR_NOME_DIVERGENTE
# 665                  2016     REVISAR_NOME_DIVERGENTE
# 349                  2012     REVISAR_NOME_DIVERGENTE
# 149                  2018     REVISAR_NOME_DIVERGENTE
# 148                  2021     REVISAR_NOME_DIVERGENTE
# 9                    2025     REVISAR_NOME_DIVERGENTE
# 424                  2019     REVISAR_NOME_DIVERGENTE
# 257                  2022     REVISAR_NOME_DIVERGENTE
# 594                  2015     REVISAR_NOME_DIVERGENTE
# 373                  2015     REVISAR_NOME_DIVERGENTE
# 423                  2012     REVISAR_NOME_DIVERGENTE
# 435                  2017     REVISAR_NOME_DIVERGENTE
# 434                  2017     REVISAR_NOME_DIVERGENTE
# 143                  2012     REVISAR_NOME_DIVERGENTE
# 142                  2012     REVISAR_NOME_DIVERGENTE
# 657                  2011     REVISAR_NOME_DIVERGENTE
# 531                  2011     REVISAR_NOME_DIVERGENTE
# 109                  2010     REVISAR_NOME_DIVERGENTE
# 515                  2017     REVISAR_NOME_DIVERGENTE
# 675                  2016     REVISAR_NOME_DIVERGENTE
# 395                  2014     REVISAR_NOME_DIVERGENTE
# 25                   2010     REVISAR_NOME_DIVERGENTE
# 23                   2010     REVISAR_NOME_DIVERGENTE
# 24                   2015     REVISAR_NOME_DIVERGENTE
# 416                  2018     REVISAR_NOME_DIVERGENTE
# 409                  2021     REVISAR_NOME_DIVERGENTE
# 474                  2011     REVISAR_NOME_DIVERGENTE
# 475                  2018     REVISAR_NOME_DIVERGENTE
# 407                  2019     REVISAR_NOME_DIVERGENTE
# 197                  2012     REVISAR_NOME_DIVERGENTE
# 129                  2018     REVISAR_NOME_DIVERGENTE
# 568                  2015     REVISAR_NOME_DIVERGENTE
# 488                  2013     REVISAR_NOME_DIVERGENTE
# 117                  2014     REVISAR_NOME_DIVERGENTE
# 716                  2012     REVISAR_NOME_DIVERGENTE
# 626                  2016     REVISAR_NOME_DIVERGENTE
# 627                  2017     REVISAR_NOME_DIVERGENTE
# 5                    2015     REVISAR_NOME_DIVERGENTE
# 4                    2014     REVISAR_NOME_DIVERGENTE
# 162                  2012     REVISAR_NOME_DIVERGENTE
# 753                  2016     REVISAR_NOME_DIVERGENTE
# 444                  2014     REVISAR_NOME_DIVERGENTE
# 44                   2015     REVISAR_NOME_DIVERGENTE
# 525                  2017     REVISAR_NOME_DIVERGENTE
# 199                  2014     REVISAR_NOME_DIVERGENTE
# 192                  2015     REVISAR_NOME_DIVERGENTE
# 585                  2025     REVISAR_NOME_DIVERGENTE
# 198                  2015     REVISAR_NOME_DIVERGENTE
# 592                  2015     REVISAR_NOME_DIVERGENTE
# 18                   2010     REVISAR_NOME_DIVERGENTE
# 306                  2025     REVISAR_NOME_DIVERGENTE
# 322                  2011     REVISAR_NOME_DIVERGENTE
# 308                  2021     REVISAR_NOME_DIVERGENTE
# 112                  2025     REVISAR_NOME_DIVERGENTE
# 113                  2025     REVISAR_NOME_DIVERGENTE
# 727                  2011     REVISAR_NOME_DIVERGENTE
# 733                  2012     REVISAR_NOME_DIVERGENTE
# 483                  2022     REVISAR_NOME_DIVERGENTE
# 336                  2011     REVISAR_NOME_DIVERGENTE
# 307                  2025     REVISAR_NOME_DIVERGENTE
# 633                  2010     REVISAR_NOME_DIVERGENTE
# 621                  2011     REVISAR_NOME_DIVERGENTE
# 634                  2010     REVISAR_NOME_DIVERGENTE
# 335                  2011     REVISAR_NOME_DIVERGENTE
# 114                  2025     REVISAR_NOME_DIVERGENTE
# 494                  2013     REVISAR_NOME_DIVERGENTE
# 495                  2022     REVISAR_NOME_DIVERGENTE
# 266                  2013     REVISAR_NOME_DIVERGENTE
# 108                  2013     REVISAR_NOME_DIVERGENTE
# 708                  2012     REVISAR_NOME_DIVERGENTE
# 707                  2012     REVISAR_NOME_DIVERGENTE
# 742                  2016     REVISAR_NOME_DIVERGENTE
# 84                   2015     REVISAR_NOME_DIVERGENTE
# 254                  2014     REVISAR_NOME_DIVERGENTE
# 85                   2015     REVISAR_NOME_DIVERGENTE
# 61                   2025     REVISAR_NOME_DIVERGENTE
#
#                                                   DENOM_SOCIAL  \
# 557                                                        NaN
# 747                                     TELEFÔNICA BRASIL S.A.
# 746                                     TELEFÔNICA BRASIL S.A.
# 273                                      TERRA SANTA AGRO S.A.
# 694                            TRONOX PIGMENTOS DO BRASIL S.A.
# 695                            TRONOX PIGMENTOS DO BRASIL S.A.
# 451                LIVETECH DA BAHIA INDÚSTRIA E COMÉRCIO S.A.
# 3                                          VALID SOLUÇÕES S.A.
# 517                                               ARTERIS S.A.
# 760                LIVETECH DA BAHIA INDÚSTRIA E COMÉRCIO S.A.
# 665           ADVANCED DIGITAL HEALTH MEDICINA PREVENTIVA S.A.
# 349                                     GRUPO CASAS BAHIA S.A.
# 149                                   EMBPAR PARTICIPAÇÕES S/A
# 148                                   EMBPAR PARTICIPAÇÕES S/A
# 9                                                    B100 S.A.
# 424                                        COGNA EDUCAÇÃO S.A.
# 257                                            PRIO FORTE S.A.
# 594                             MASSA FALIDA DE POMIFRUTAS S/A
# 373                                                  PRIO S.A.
# 423                                        COGNA EDUCAÇÃO S.A.
# 435                    JPSP INVESTIMENTOS E PARTICIPAÇÕES S.A.
# 434                    JPSP INVESTIMENTOS E PARTICIPAÇÕES S.A.
# 143                          OI S.A. - EM RECUPERAÇÃO JUDICIAL
# 142                          OI S.A. - EM RECUPERAÇÃO JUDICIAL
# 657           ADVANCED DIGITAL HEALTH MEDICINA PREVENTIVA S.A.
# 531                       COMPANHIA BRASILEIRA DE DISTRIBUIÇÃO
# 109                                       BANCO DO BRASIL S.A.
# 515                                            PRIO FORTE S.A.
# 675                                  ENGIE BRASIL ENERGIA S.A.
# 395            FICTOR ALIMENTOS S.A. - EM RECUPERAÇÃO JUDICIAL
# 25                                                   RUMO S.A.
# 23                                                   RUMO S.A.
# 24                                                   RUMO S.A.
# 416                                              IGUATEMI S.A.
# 409                               BLUE TECH SOLUTIONS EQI S.A.
# 474                                              IGUATEMI S.A.
# 475                                              IGUATEMI S.A.
# 407                               BLUE TECH SOLUTIONS EQI S.A.
# 197                   CENTRAIS ELETRICAS DE SANTA CATARINA S.A
# 129              ALPER CONSULTORIA E CORRETORA DE SEGUROS S.A.
# 568                                                 ÉVORA S.A.
# 488                                                 ENEVA S.A.
# 117                                               BANCO PAN SA
# 716              TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.
# 626           WLM PART. E COMÉRCIO DE MÁQUINAS E VEÍCULOS S.A.
# 627           WLM PART. E COMÉRCIO DE MÁQUINAS E VEÍCULOS S.A.
# 5                                          SOMOS EDUCAÇÃO S.A.
# 4                                          SOMOS EDUCAÇÃO S.A.
# 162             CAMARGO CORREA DESENVOLVIMENTO  IMOBILIARIO SA
# 753           ADVANCED DIGITAL HEALTH MEDICINA PREVENTIVA S.A.
# 444                                       PRUMO LOGÍSTICA S.A.
# 44            ADVANCED DIGITAL HEALTH MEDICINA PREVENTIVA S.A.
# 525          WIZ CO PARTICIPAÇÕES E CORRETAGEM DE SEGUROS S.A.
# 199          ENERGISA MATO GROSSO-DISTRIBUIDORA DE ENERGIA S/A
# 192                      CIELO S.A. - INSTITUIÇÃO DE PAGAMENTO
# 585                                  ARANDU INVESTIMENTOS S.A.
# 198          ENERGISA MATO GROSSO-DISTRIBUIDORA DE ENERGIA S/A
# 592                                   RJ CAPITAL PARTNERS S.A.
# 18                       AGRA EMPREENDIMENTOS IMOBILIÁRIOS S/A
# 306              EQUATORIAL PARÁ DISTRIBUIDORA DE ENERGIA S.A.
# 322                                    VALE FERTILIZANTES S.A.
# 308              EQUATORIAL PARÁ DISTRIBUIDORA DE ENERGIA S.A.
# 112                                      BANCO BTG PACTUAL S/A
# 113                                      BANCO BTG PACTUAL S/A
# 727                                           COSTA PINTO S.A.
# 733                                         UNIVERSO ONLINE SA
# 483                                           BANCO MODAL S.A.
# 336      MASSA FALIDA DA FÁBRICA DE TECIDOS CARLOS RENAUX S.A.
# 307              EQUATORIAL PARÁ DISTRIBUIDORA DE ENERGIA S.A.
# 633  FIACAO E TECELAGEM SAO JOSE S/A - EM RECUPERAÇÃO JUDICIAL
# 621                            PEARSON SISTEMAS DO BRASIL S.A.
# 634  FIACAO E TECELAGEM SAO JOSE S/A - EM RECUPERAÇÃO JUDICIAL
# 335      MASSA FALIDA DA FÁBRICA DE TECIDOS CARLOS RENAUX S.A.
# 114                                      BANCO BTG PACTUAL S/A
# 494                                     METALGRAFICA IGUACU SA
# 495                                     METALGRAFICA IGUACU SA
# 266             METALURGICA DUQUE SA - EM RECUPERAÇÃO JUDICIAL
# 108                             BANCO DO NORDESTE DO BRASIL SA
# 708                          TELE NORTE LESTE PARTICIPAÇÕES SA
# 707                          TELE NORTE LESTE PARTICIPAÇÕES SA
# 742                                       VIGOR ALIMENTOS S.A.
# 84                  BANK OF CHINA (BRASIL) BANCO MÚLTIPLO S.A.
# 254                                      DHB IND E COMERCIO SA
# 85                  BANK OF CHINA (BRASIL) BANCO MÚLTIPLO S.A.
# 61                            AZEVEDO & TRAVASSOS ENERGIA S.A.
#
#      score_nome_cadastro
# 557             0.000000
# 747            25.000000
# 746            25.000000
# 273            28.571429
# 694            30.000000
# 695            30.000000
# 451            33.333333
# 3              33.333333
# 517            33.333333
# 760            33.333333
# 665            36.363636
# 349            36.363636
# 149            36.363636
# 148            36.363636
# 9              37.500000
# 424            40.000000
# 257            40.000000
# 594            40.000000
# 373            40.000000
# 423            40.000000
# 435            41.666667
# 434            41.666667
# 143            41.666667
# 142            41.666667
# 657            41.666667
# 531            43.478261
# 109            44.444444
# 515            44.444444
# 675            44.444444
# 395            46.153846
# 25             46.153846
# 23             46.153846
# 24             46.153846
# 416            47.058824
# 409            47.058824
# 474            47.058824
# 475            47.058824
# 407            47.058824
# 197            50.000000
# 129            50.000000
# 568            50.000000
# 488            50.000000
# 117            50.000000
# 716            52.631579
# 626            53.333333
# 627            53.333333
# 5              54.545455
# 4              54.545455
# 162            54.545455
# 753            54.545455
# 444            57.142857
# 44             57.142857
# 525            58.333333
# 199            60.000000
# 192            60.000000
# 585            60.000000
# 198            60.000000
# 592            63.157895
# 18             63.157895
# 306            66.666667
# 322            66.666667
# 308            66.666667
# 112            66.666667
# 113            66.666667
# 727            66.666667
# 733            66.666667
# 483            66.666667
# 336            66.666667
# 307            66.666667
# 633            66.666667
# 621            66.666667
# 634            66.666667
# 335            66.666667
# 114            66.666667
# 494            70.588235
# 495            70.588235
# 266            71.428571
# 108            72.727273
# 708            72.727273
# 707            72.727273
# 742            75.000000
# 84             75.000000
# 254            75.000000
# 85             75.000000
# 61             77.777778

# %% [markdown]
# ## Passo 5 — Inventário de `codigo_cvm` presentes nos arquivos DFP/ITR
#
# Antes de cruzar com os tickers já validados, construímos um inventário de
# todos os pares `(codigo_cvm, ano)` que efetivamente existem nos arquivos
# parquet baixados. Usamos os arquivos "principais" (`dfp_cia_aberta_AAAA-AAAA.parquet`
# e `itr_cia_aberta_AAAA-AAAA.parquet`) — eles contêm `CD_CVM`, `DT_REFER` e
# `DENOM_CIA` para toda companhia com demonstrativo naquele ano, sem precisar
# ler os arquivos grandes de cada tipo de demonstrativo (BPA, BPP, DRE, etc.),
# já que o conjunto de `codigo_cvm` é o mesmo entre eles.

# %%
import duckdb

pasta_interim = pasta_anterior / "data/interim"

arquivos_principais = {
    "dfp": sorted((pasta_interim / "02_dfp_concatenated").glob("dfp_cia_aberta_*.parquet"))[0],
    "itr": sorted((pasta_interim / "02_itr_concatenated").glob("itr_cia_aberta_*.parquet"))[0],
}

# Confere que peguei o arquivo "principal" certo (o mais leve, sem sufixo de demonstrativo)
for origem, arq in arquivos_principais.items():
    print(origem, "->", arq.name)
# Out:
# dfp -> dfp_cia_aberta_2010-2025.parquet
# itr -> itr_cia_aberta_2011-2025.parquet

# %% [markdown]
# Extrai, de cada arquivo, os pares únicos `(codigo_cvm, ano, denom_cia)`.
# `ano` é derivado de `DT_REFER` (data de referência do demonstrativo).

# %%
def extrair_codigos_cvm(arquivo_parquet: Path, origem: str) -> pd.DataFrame:
    df = duckdb.sql(f"""
        SELECT DISTINCT
            CD_CVM AS codigo_cvm,
            CAST(SUBSTR(DT_REFER, 1, 4) AS INTEGER) AS ano,
            DENOM_CIA AS denom_cia
        FROM '{arquivo_parquet}'
    """).df()
    df["codigo_cvm"] = df["codigo_cvm"].astype(str).apply(normalizar_cvm)
    df["origem"] = origem
    return df


codigos_cvm_parquet = pd.concat(
    [extrair_codigos_cvm(arq, origem) for origem, arq in arquivos_principais.items()],
    ignore_index=True,
)

print(f"Total de pares (codigo_cvm, ano, origem): {len(codigos_cvm_parquet)}")
codigos_cvm_parquet
# Out:
# Total de pares (codigo_cvm, ano, origem): 20999
#       codigo_cvm   ano                                denom_cia origem
# 0          14451  2010   COMPANHIA ENERGÉTICA DE BRASÍLIA - CEB    dfp
# 1          14613  2010  NEUMARKT TRADE AND FINANCIAL CENTER S/A    dfp
# 2          15334  2010                       BOMBRIL HOLDING SA    dfp
# 3          16195  2010                              AMERICEL SA    dfp
# 4          16551  2010   WTC RIO EMPREEND. E PARTICIPAÇÕES S.A.    dfp
# ...          ...   ...                                      ...    ...
# 20994       8451  2025                           MARCOPOLO S.A.    itr
# 20995       8192  2025               TREVISA INVESTIMENTOS S.A.    itr
# 20996       6629  2025        HERCULES S.A. FABRICA DE TALHERES    itr
# 20997       2429  2025             IRANI PAPEL E EMBALAGEM S.A.    itr
# 20998      25950  2025           TRÊS TENTOS AGROINDUSTRIAL S/A    itr
#
# [20999 rows x 4 columns]

# %% [markdown]
# ### Códigos CVM únicos
#
# Lista consolidada de todo `codigo_cvm` que aparece em pelo menos um
# demonstrativo (DFP ou ITR), independentemente do ano — é o universo total
# de companhias com dados financeiros disponíveis nos parquet.

# %%
codigos_cvm_unicos = (
    codigos_cvm_parquet
    .groupby("codigo_cvm")
    .agg(
        primeiro_ano_dfp_itr=("ano", "min"),
        ultimo_ano_dfp_itr=("ano", "max"),
        anos_disponiveis=("ano", lambda s: sorted(set(s))),
        origens=("origem", lambda s: sorted(set(s))),
        denom_cia_mais_recente=("denom_cia", "last"),
    )
    .reset_index()
)

print(f"Total de codigo_cvm únicos nos arquivos DFP/ITR: {len(codigos_cvm_unicos)}")
codigos_cvm_unicos
# Out:
# Total de codigo_cvm únicos nos arquivos DFP/ITR: 1228
#      codigo_cvm  primeiro_ano_dfp_itr  ultimo_ano_dfp_itr  \
# 0          1023                  2010                2025
# 1         10456                  2010                2025
# 2         10472                  2010                2023
# 3         10561                  2010                2025
# 4         10596                  2010                2013
# ...         ...                   ...                 ...
# 1223       9717                  2010                2025
# 1224       9784                  2010                2011
# 1225       9857                  2010                2012
# 1226       9954                  2010                2025
# 1227       9989                  2010                2025
#
#                                                  anos_disponiveis     origens  \
# 0     [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2...  [dfp, itr]
# 1     [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2...  [dfp, itr]
# 2     [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2...  [dfp, itr]
# 3     [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2...  [dfp, itr]
# 4                                        [2010, 2011, 2012, 2013]  [dfp, itr]
# ...                                                           ...         ...
# 1223  [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2...  [dfp, itr]
# 1224                                                 [2010, 2011]  [dfp, itr]
# 1225                                           [2010, 2011, 2012]  [dfp, itr]
# 1226  [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2...  [dfp, itr]
# 1227  [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2...  [dfp, itr]
#
#                                 denom_cia_mais_recente
# 0                                      BCO BRASIL S.A.
# 1                                      ALPARGATAS S.A.
# 2     SARAIVA LIVREIROS S.A. - EM RECUPERAÇÃO JUDICIAL
# 3                  SEIVA S.A. - FLORESTAS E INDÚSTRIAS
# 4                        SERGEN SERVS GERAIS DE ENG SA
# ...                                                ...
# 1223                           PORTUENSE FERRAGENS S/A
# 1224                            PRONOR PETROQUIMICA SA
# 1225                              QGN PARTICIPAÇÕES SA
# 1226                                ALFA HOLDINGS S.A.
# 1227            REFINARIA DE PETROLEOS MANGUINHOS S.A.
#
# [1228 rows x 6 columns]

# %% [markdown]
# ## Passo 6 — Cruzar tickers validados com a cobertura DFP/ITR
#
# Para cada ticker com `status_final` já resolvido (`ALTA_VIA_FCA` ou
# `ALTA_VIA_CADASTRO`), verificamos:
#
# 1. se o `codigo_cvm` existe em algum ano nos parquet (`tem_demonstrativo`);
# 2. se existe demonstrativo **dentro do período em que o ticker foi
#    negociado** (`primeiro_ano_observado`–`ultimo_ano_observado`) — o que
#    importa de fato para montar indicadores;
# 3. quantos anos de demonstrativo existem nesse período
#    (`anos_cobertos_no_periodo`).
#
# Isso separa dois problemas diferentes: `codigo_cvm` correto mas **sem**
# demonstrativo no período (situação real de dados faltantes) versus
# `codigo_cvm` correto e coberto (pronto para uso).

# %%
validados = auditoria_final[
    auditoria_final["status_final"].isin(["ALTA_VIA_FCA", "ALTA_VIA_CADASTRO"])
].copy()

mapa_anos_por_cvm = codigos_cvm_unicos.set_index("codigo_cvm")["anos_disponiveis"].to_dict()


def cobertura_dfp_itr(row):
    anos_disponiveis = mapa_anos_por_cvm.get(row["codigo_cvm_norm"])
    if anos_disponiveis is None:
        return pd.Series({
            "tem_demonstrativo": False,
            "anos_cobertos_no_periodo": [],
            "qtd_anos_cobertos_no_periodo": 0,
        })

    anos_no_periodo = [
        ano for ano in anos_disponiveis
        if row["primeiro_ano_observado"] <= ano <= row["ultimo_ano_observado"]
    ]

    return pd.Series({
        "tem_demonstrativo": True,
        "anos_cobertos_no_periodo": anos_no_periodo,
        "qtd_anos_cobertos_no_periodo": len(anos_no_periodo),
    })


validados = pd.concat([validados, validados.apply(cobertura_dfp_itr, axis=1)], axis=1)

print("Tem ao menos 1 ano de demonstrativo no período observado:",
      (validados["qtd_anos_cobertos_no_periodo"] > 0).sum(), "de", len(validados))

print("\nSem NENHUM demonstrativo (mesmo fora do período):",
      (~validados["tem_demonstrativo"]).sum())

print("\nTem demonstrativo, mas fora do período observado do ticker:",
      ((validados["tem_demonstrativo"]) & (validados["qtd_anos_cobertos_no_periodo"] == 0)).sum())
# Out:
# Tem ao menos 1 ano de demonstrativo no período observado: 677 de 689
#
# Sem NENHUM demonstrativo (mesmo fora do período): 12
#
# Tem demonstrativo, mas fora do período observado do ticker: 0

# %% [markdown]
# ### Casos sem cobertura
#
# Tickers cujo `codigo_cvm` não possui demonstrativos financeiros (DFP/ITR)
# disponíveis nos arquivos da CVM para o período de 2010 a 2025.
#
# Esses ativos são removidos do universo investível, pois não é possível obter
# seus indicadores fundamentalistas de forma consistente. Como o objetivo do
# projeto é construir uma base de dados para backtests fundamentados, manter
# esses ativos resultaria em empresas sem informações financeiras, comprometendo
# a qualidade e a consistência das análises.

# %%
mask_sem_cobertura = validados["qtd_anos_cobertos_no_periodo"] == 0
tickers_sem_cobertura = validados.loc[mask_sem_cobertura, "TICKER"]

auditoria_final.loc[
    auditoria_final["TICKER"].isin(tickers_sem_cobertura), "status_final"
] = "SEM_DFP_OU_ITR"

validados.loc[mask_sem_cobertura, "status_final"] = "SEM_DFP_OU_ITR"

sem_cobertura = validados[validados["qtd_anos_cobertos_no_periodo"] == 0][
    ["TICKER", "codigo_cvm", "status_final", "primeiro_ano_observado",
     "ultimo_ano_observado", "tem_demonstrativo"]
].sort_values("TICKER")

print(f"--- {len(sem_cobertura)} tickers sem cobertura DFP/ITR no período observado ---")
sem_cobertura
# Out:
# --- 12 tickers sem cobertura DFP/ITR no período observado ---
#     TICKER codigo_cvm    status_final  primeiro_ano_observado  \
# 6    ABYA3      20206  SEM_DFP_OU_ITR                    2010
# 7    ACGU3      20940  SEM_DFP_OU_ITR                    2010
# 17   AGEI3      21911  SEM_DFP_OU_ITR                    2010
# 55   AVIL3        108  SEM_DFP_OU_ITR                    2010
# 362  GVTT3      20117  SEM_DFP_OU_ITR                    2010
# 426  KSSA3      20249  SEM_DFP_OU_ITR                    2010
# 456  MARI3      20761  SEM_DFP_OU_ITR                    2010
# 463  MEDI3      20273  SEM_DFP_OU_ITR                    2010
# 667  SZPQ4      19267  SEM_DFP_OU_ITR                    2010
# 723  TVIT3      21768  SEM_DFP_OU_ITR                    2010
# 765  WISA3      14397  SEM_DFP_OU_ITR                    2011
# 766  WISA4      14397  SEM_DFP_OU_ITR                    2011
#
#      ultimo_ano_observado  tem_demonstrativo
# 6                    2010              False
# 7                    2010              False
# 17                   2010              False
# 55                   2011              False
# 362                  2010              False
# 426                  2010              False
# 456                  2010              False
# 463                  2010              False
# 667                  2010              False
# 723                  2010              False
# 765                  2012              False
# 766                  2012              False

# %% [markdown]
# ## Passo 7 — Exportação final
#
# Consolida tudo (status de auditoria + cobertura DFP/ITR) e exporta:
#
# - `auditoria_codigo_cvm_completa.csv`: todos os, com status
#   final e indicadores de cobertura.
# - `auditoria_codigo_cvm_para_revisao.csv`: apenas os casos que restaram
#   para checagem manual (nome divergente / código inexistente), do mais
#   duvidoso ao menos duvidoso.
# - `codigo_cvm_unicos_dfp_itr.csv`: lista de referência com todo `codigo_cvm`
#   disponível nos parquet — útil depois para localizar rapidamente os dados
#   de uma empresa sem precisar escanear os arquivos grandes de novo.

# %%
pasta_saida = pasta_anterior / "data/interim"

# 1. Junta cobertura DFP/ITR de volta no dataframe completo (quem não foi
#    validado nesta etapa fica com NaN nessas colunas — é esperado)
colunas_cobertura = ["TICKER", "tem_demonstrativo", "qtd_anos_cobertos_no_periodo"]

auditoria_export = auditoria_final.merge(
    validados[colunas_cobertura], on="TICKER", how="left"
)

# 2. Arquivo completo
colunas_finais = [
    "TICKER", "codigo_cvm", "codigo_isin", "primeiro_ano_observado",
    "ultimo_ano_observado", "status_final", "DENOM_SOCIAL",
    "score_nome_cadastro", "tem_demonstrativo", "qtd_anos_cobertos_no_periodo",
]
colunas_finais = [c for c in colunas_finais if c in auditoria_export.columns]

auditoria_export[colunas_finais].to_csv(
    pasta_saida / "07_audit/complete_code_cvm.csv", sep=";", index=False
)

# 3. Arquivo apenas com pendências de revisão manual
revisar_export = auditoria_export[
    auditoria_export["status_final"].isin(["REVISAR_NOME_DIVERGENTE", "REVISAR_CODIGO_INEXISTENTE"])
].sort_values("score_nome_cadastro")

revisar_export[colunas_finais].to_csv(
    pasta_saida / "07_audit/revision_code_cvm.csv", sep=";", index=False
)

# 4. Lista de referência de codigo_cvm disponíveis nos parquet
codigos_cvm_unicos.to_csv(
    pasta_saida / "07_audit/unique_code_cvm_for_dfp-itr.csv", sep=";", index=False
)

print("Exportado:")
print(" -", pasta_saida / "07_audit/complete_code_cvm.csv", f"({len(auditoria_export)} linhas)")
print(" -", pasta_saida / "07_audit/revision_code_cvm.csv", f"({len(revisar_export)} linhas)")
print(" -", pasta_saida / "07_audit/unique_code_cvm_for_dfp-itr.csv", f"({len(codigos_cvm_unicos)} linhas)")
# Out:
# Exportado:
#  - c:\Users\paulo\Desktop\Python\brazilian_financial_database\data\interim\07_audit\complete_code_cvm.csv (774 linhas)
#  - c:\Users\paulo\Desktop\Python\brazilian_financial_database\data\interim\07_audit\revision_code_cvm.csv (85 linhas)
#  - c:\Users\paulo\Desktop\Python\brazilian_financial_database\data\interim\07_audit\unique_code_cvm_for_dfp-itr.csv (1228 linhas)
