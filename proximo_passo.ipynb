# %% [markdown]
# ALGUNS TICKERS FORAM ADICIONADOS NO CSV TICKER_AND_CODE_CVM_MAPPING.
# FALTA ADICIONAR OS CODIGOS CVM CORRESPONDENTES
#
# APOS ISSO, NO NOTEBOOK 05, VALIDAR MANUALMENTE OS CODIGOS NAO VALIDADOS AUTOMATICAMENTE
